# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

# %%
df = pd.read_csv(r'C:\Users\vijay\OneDrive\Desktop\ML_PRACTICE\LINEAR_REGRESSION\DATASETS\house_price_dataset_1k.xls')

# %%
df.head(10)
# Out:
#    area_sqft  bedrooms  age_years  distance_to_city_km     price
# 0     2185.4         4       23.4                19.26  307100.0
# 1     4778.2         2       34.1                 8.89  593000.0
# 2     3794.0         5       45.6                19.77  479800.0
# 3     3194.0         3       41.3                 6.71  411600.0
# 4     1202.1         3       22.5                23.67  165800.0
# 5     1202.0         3       19.4                 3.77  193500.0
# 6      761.4         1       12.0                26.91  116400.0
# 7     4397.8         1       18.6                25.29  539000.0
# 8     3205.0         3        5.6                20.52  424300.0
# 9     3686.3         4       48.6                 2.49  488300.0

# %%
X  = df.drop(['price'],axis=1)
Y  = df['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size = 0.2,random_state=42)

# %%
model = LinearRegression()
scale = StandardScaler()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_train_scale = scale.fit_transform(X_train)
X_test_scale = scale.transform(X_test)

# %%
model.fit(X_train_scale,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test_scale,)

# %%
model.score(X_test,y_test)
# Out:
# c:\Users\rupab\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:458: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# -9015015.67817619

# %%
r2_score(y_test, y_pred)
# Out:
# 0.993941171203038
